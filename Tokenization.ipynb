# %%
# Chargement du paquet spacy
# REMARQUE: Ce fichier ipynb doit être dans le même dossier que les dossiers du corpus
import spacy
nlp = spacy.load("fr_core_news_sm")

# %%
list_ = open("CORPUS TXT/Capgemini ~ l’expertise de la donnée au service de la continuité numérique.txt", encoding='utf-8').read().split(' ')

# %%
separator = ' '
# Tout le texte comme une seule string
test = separator.join(list_)
# Out:
# l’expertise de la donnée au service de la
# continuité numérique
# Quels sont les domaines d’applications au sein
# desquels Capgemini est le plus investi ?
# Nous travaillons dans des secteurs très concurrentiels tels que les Services
# financiers, l’automobile, la distribution, la santé, l’industrie. Que ce soit au niveau
# du digital, de la data, du cloud, ou de la maintenance prédictive à travers l’IoT,
# Capgemini déploie ses expertises à travers des engagements partenariaux de long
# terme pour guider nos clients dans leur transformation digitale. Notre expertise
# sectorielle et data s’est, par exemple, manifestée avec Airbus lorsque l’avionneur
# a voulu transformer son business model classique de vente d’avions vers un
# business model beaucoup plus data centric de vente de services autour de ses avions
# avec le projet Skywise.
# Capgemini, en combinant ses différentes expertises permet à ses clients
# ...

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
tokenized = tokenizer.tokenize(test)
tokenized
# Out:
# ['CES',
#  '2019',
#  '5',
#  'tendances',
#  'technos',
#  'à',
#  'surveiller',
#  'de',
#  'près',
#  'et',
#  'quelques',
#  'autres',
#  'insights',
#  'à',
#  'savoir',
#  'Traditionnellement',
#  'le',
#  'CES',
#  'dévoile',
#  'les',
#  'tendances',
#  'high',
#  'tech',
#  'de',
#  'l',
#  'année',
#  'Si',
#  'pendant',
#  'des',
#  'années',
#  'le',
#  'salon',
#  'était',
#  'très',
#  'orienté',
#  'B2C',
#  'la',
#  'donne',
#  'a',
#  'changé',
#  'Les',
#  'innovations',
#  'présentées',
#  'touchent',
#  'désormais',
#  'aussi',
#  'l',
#  'univers',
#  'B2B',
#  'Résultat',
#  'de',
#  'nombreuses',
#  'délégations',
#  'dans',
#  'des',
#  'marchés',
#  'aussi',
#  'divers',
#  'que',
#  'la',
#  'banque',
#  'l',
#  'armée',
#  'la',
#  'logistique',
#  'la',
#  'santé',
#  'ou',
#  'la',
#  'pharmacie',
#  'font',
#  'aujourd',
#  'hui',
#  'le',
#  'déplacement',
#  'à',
#  'Las',
#  'Vegas',
#  'Objectif',
#  'détecter',
#  'les',
#  'technologies',
# ...

# %%
# Chargement du paquet Natural Language ToolKit (nltk)
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gutor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Utilisation de la liste de mots vides du paquet nltk
from nltk.corpus import stopwords
stopWords = set(stopwords.words('french'))

# %%
clean_words = []
for token in tokenized:
    if token not in stopWords:
        clean_words.append(token)
clean_words
# Out:
# ['CES',
#  '2019',
#  '5',
#  'tendances',
#  'technos',
#  'surveiller',
#  'près',
#  'quelques',
#  'autres',
#  'insights',
#  'savoir',
#  'Traditionnellement',
#  'CES',
#  'dévoile',
#  'tendances',
#  'high',
#  'tech',
#  'année',
#  'Si',
#  'pendant',
#  'années',
#  'salon',
#  'très',
#  'orienté',
#  'B2C',
#  'donne',
#  'a',
#  'changé',
#  'Les',
#  'innovations',
#  'présentées',
#  'touchent',
#  'désormais',
#  'aussi',
#  'univers',
#  'B2B',
#  'Résultat',
#  'nombreuses',
#  'délégations',
#  'marchés',
#  'aussi',
#  'divers',
#  'banque',
#  'armée',
#  'logistique',
#  'santé',
#  'pharmacie',
#  'font',
#  'aujourd',
#  'hui',
#  'déplacement',
#  'Las',
#  'Vegas',
#  'Objectif',
#  'détecter',
#  'technologies',
#  'vont',
#  'révolutionner',
#  'usages',
#  'anticiper',
#  'éviter',
#  'faire',
#  'disrupter',
#  'Alors',
#  'quelles',
#  'tendances',
#  'technologiques',
#  'faut',
#  'attendre',
#  'CES',
#  '2019',
#  'Voici',
#  '5',
#  'axes',
# ...

# %%
# Plan B
def return_POS(sentence):
    # Tokeniser la phrase
    doc = nlp(sentence)
    # Retourner les étiquettes lemmatizés de chaque token
    #return [(X.lemma_, X.pos_) for X in doc if X.pos_ in(('NOUN','VERB','ADJ')) and str(X) != '…']
    return [(X.lemma_) for X in doc if X.pos_ in(('NOUN','VERB','ADJ')) and str(X) != '…']

# %%
return_lemma(test)
# Out:
# ['expertise',
#  'donnée',
#  'service',
#  'continuité',
#  'numérique',
#  'quel',
#  'domaine',
#  'application',
#  'sein',
#  'desquel',
#  'investir',
#  'travailler',
#  'secteur',
#  'concurrentiel',
#  'tel',
#  'service',
#  'financier',
#  'automobile',
#  'distribution',
#  'santé',
#  'industrie',
#  'niveau',
#  'digital',
#  'data',
#  'cloud',
#  'maintenance',
#  'prédictif',
#  'travers',
#  'l’',
#  'déployer',
#  'expertise',
#  'travers',
#  'engagement',
#  'partenarial',
#  'long',
#  'terme',
#  'guider',
#  'client',
#  'transformation',
#  'digital',
#  'expertise',
#  'sectoriel',
#  'exemple',
#  'manifester',
#  'l’',
#  'vouloir',
#  'transformer',
#  'business',
#  'classique',
#  'vente',
#  'avion',
#  'centric',
#  'vente',
#  'service',
#  'avion',
#  'projet',
#  'combiner',
#  'différent',
#  'expertise',
#  'permettre',
#  'client',
#  'faire',
#  'donnée',
#  'levier',
#  'continuité',
#  'numérique',
#  'pouvoir',
#  'dire',
#  'donnée',
# ...

# %%
import numpy as np

def return_word_embedding(sentence):
    # Tokeniser la phrase
    doc = nlp(sentence)
    # Retourner le vecteur lié à chaque token
    return [(X.vector) for X in doc]

# %%
return_word_embedding(test)
# Out:
# [array([ 6.9641666 ,  1.6892564 ,  2.8078547 ,  3.1602092 ,  0.3596562 ,
#         -2.2247105 ,  0.60098207,  0.7707899 , -0.10295153,  1.8523061 ,
#         -0.61194   , -2.312756  ,  0.32744706, -3.6550112 , -0.3143522 ,
#         -1.6955142 ,  0.2122606 ,  2.314558  ,  1.4809232 , -2.8534002 ,
#         -2.5756083 ,  1.6980226 ,  0.11349976,  4.798283  , -0.9136684 ,
#          1.1046933 ,  0.94290507, -0.07458892, -6.160452  , -2.9308352 ,
#         -1.2019205 , -2.993437  , -1.8107346 ,  0.540964  , -0.3830212 ,
#          1.6983209 , -1.2772067 , -0.44977286, -1.6231498 ,  0.1689381 ,
#          1.5851017 ,  1.9105692 , -0.34679842, -0.6020373 ,  1.0975138 ,
#          1.4501797 ,  1.7848306 ,  3.9046059 ,  0.2910644 , -2.255869  ,
#          3.4555898 , -3.156755  ,  5.510238  ,  0.3025707 , -2.8339367 ,
#          1.3376496 ,  1.0359602 ,  1.0701444 ,  2.1965117 , -1.4993033 ,
#         -2.2982616 , -5.4613543 , -1.4306573 ,  2.818259  , -0.67959714,
# ...

# %%
def return_tensor(sentence):
    # Tokeniser la phrase
    doc = nlp(sentence)
    # Retourner la moyenne des vecteurs pour chaque phrase
    return np.mean([(X.vector) for X in doc], axis=0)

# %%
test_2 = "Le réseau sera bientot rétabli à Marseille"
test_3 = "La panne réseau affecte plusieurs utilisateurs de l'opérateur"
test_4 = "Il fait 18 degrés ici"

# %%
np.linalg.norm(return_tensor(test)-return_tensor(test_2))
# Out:
# 9.236941

# %%
np.linalg.norm(return_tensor(test)-return_tensor(test_3))
# Out:
# 9.8653965

# %%
np.linalg.norm(return_tensor(test)-return_tensor(test_4))
# Out:
# 11.712879

# %%
# Matrice de distances pour donner à manger pour sk.learn

# %%
import os
import spacy
from nltk.tokenize import RegexpTokenizer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
nlp = spacy.load("fr_core_news_sm")

# Loading the names from the files in the corpus
files = os.listdir("CORPUS TXT")
for filename in files:
    list_ = open("CORPUS TXT/"+filename, encoding='utf-8').read().split(' ')
    separator = ' '
    # Tout le texte comme une seule string
    txt = separator.join(list_)
    tokenizer = RegexpTokenizer(r'\w+')
    tokenized = tokenizer.tokenize(txt)
    stopWords = set(stopwords.words('french'))
    clean_words = []
    for token in tokenized:
        if token not in stopWords:
            clean_words.append(token)
    with open("CORPUS TOKEN/out_" + filename, "a") as txtfile:
        for word in clean_words:
            print(word, file=txtfile)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gutor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Plan B
def return_lemma(sentence):
    # Tokeniser la phrase
    doc = nlp(sentence)
    # Retourner les étiquettes lemmatizés de chaque token
    #return [(X.lemma_, X.pos_) for X in doc if X.pos_ in(('NOUN','VERB','ADJ')) and str(X) != '…']
    return [str(X.lemma_) for X in doc if X.pos_ in(('NOUN','VERB','ADJ')) and str(X) != '…' and not X.is_punct]

# %%
list_ = open("CORPUS LEMMA/L_out_Après le RGPD, la Commission européenne préparerait une réglementation sur l'intelligence artificielle.txt", encoding='utf-8').read().split(' ')
# Tout le texte comme une seule string
txt = ' '.join(list_)
print(txt)
# Out:
# commission
# européen
# préparer
# réglementation
# intelligence
# artificiel
# européen
# office
# pionnier
# mondial
# matière
# protection
# donnée
# pouvoir
# consolider
# statut
# nouveau
# réglementation
# intelligence
# artificiel
# financial
# article
# août
# commission
# européen
# planche
# projet
# loi
# étendre
# droit
# citoyen
# européen
# donnée
# lier
# domaine
# général
# protection
# donnée
# couvrir
# donnée
# biométrique
# nouveau
# projet
# aller
# représenter
# nouveau
# standard
# mondial
# régulation
# intelligence
# artificielle
# ft
# imposer
# droit
# regard
# utilisation
# donnée
# reconnaissance
# facial
# appliquer
# fois
# gouvernement
# force
# ordre
# entreprise
# privé
# projet
# porter
# prochain
# président
# commission
# européen
# a
# noter
# pays
# globalemer
# protéger
# matière
# autre
# pays
# travers
# suffire
# prendre
# tête
# commission
# européen
# premier
# novembre
# prévoit
# présenter
# projet
# loi
# implication
# éthique
# humain
# ...

# %%
return_lemma(txt)
# Out:
# ['commission',
#  'européen',
#  'préparer',
#  'réglementation',
#  'intelligence',
#  'artificiel',
#  'européen',
#  'office',
#  'pionnier',
#  'mondial',
#  'matière',
#  'protection',
#  'donner',
#  'pouvoir',
#  'consolider',
#  'statut',
#  'nouveau',
#  'réglementation',
#  'intelligence',
#  'artificiel',
#  'article',
#  'août',
#  'commission',
#  'européen',
#  'planche',
#  'projet',
#  'loi',
#  'étendre',
#  'droit',
#  'citoyen',
#  'européen',
#  'donner',
#  'lier',
#  'domaine',
#  'général',
#  'protection',
#  'donner',
#  'couvrir',
#  'donner',
#  'biométrique',
#  'nouveau',
#  'projet',
#  'aller',
#  'représenter',
#  'nouveau',
#  'standard',
#  'mondial',
#  'régulation',
#  'intelligence',
#  'artificiel',
#  'ft',
#  'imposer',
#  'droit',
#  'regard',
#  'utilisation',
#  'donner',
#  'reconnaissance',
#  'facial',
#  'appliquer',
#  'fois',
#  'gouvernement',
#  'force',
#  'ordre',
#  'entreprise',
#  'priver',
#  'projet',
#  'porter',
# ...

# %%
# Loading the names from the files in the corpus
files = os.listdir("CORPUS TXT")
for filename in files:
    list_ = open("CORPUS TXT/"+filename, encoding='utf-8').read().split(' ')
    separator = ' '
    # Tout le texte comme une seule string
    txt = separator.join(list_)
    lemma_list = return_lemma(txt)
    with open("CORPUS LEMMA/L_out_" + filename, "a", encoding="utf-8") as txtfile:
        for lemma in lemma_list:
            print(lemma, file=txtfile)

# %%
import spacy
nlp = spacy.load("fr_core_news_lg")
# Ne pas oublier d'installer le package -> python -m spacy download fr_core_news_lg
test_2 = "Le réseau sera bientot rétabli à Marseille"
test_3 = "La panne réseau affecte plusieurs utilisateurs de l'opérateur"
test_4 = "Il fait 18 degrés ici"

# %%
doc2 = nlp(test_2)
doc3 = nlp(test_3)
doc4 = nlp(test_4)
doc5 = nlp(txt)
print(1 - doc2.similarity(doc3))
print(1 - doc2.similarity(doc4))
print(1 - doc3.similarity(doc4))
doc5.vector
# Out:
# 0.6185936421937224
# 0.8320418647409425
# 0.9480136531451722
# array([ 1.10327341e-01, -7.16303568e-03, -4.88293320e-01,  7.69027591e-01,
#        -7.15151429e-01,  4.45399404e-01, -1.38472974e-01,  7.52806067e-01,
#         3.92993003e-01, -2.27557987e-01, -3.60274553e-01, -9.29373279e-02,
#        -3.36908162e-01, -1.17627275e+00,  5.15259989e-02, -7.15174302e-02,
#         6.96677089e-01, -2.51243174e-01,  3.74705911e-01,  3.37416410e-01,
#         2.90877104e-01,  1.80480272e-01,  1.11036403e-02, -2.43283398e-02,
#        -7.85943449e-01,  2.18478143e-01,  1.25917615e-02,  2.99305886e-01,
#         1.05395518e-01,  2.64818281e-01,  3.44602503e-02, -1.05656907e-01,
#        -2.52527148e-01,  1.08657509e-01,  5.24990916e-01,  4.80833113e-01,
#         4.08290088e-01, -4.39148664e-01,  4.35902417e-01, -4.88268845e-02,
#         6.81738198e-01, -1.41986132e-01,  1.53603211e-01,  4.33922678e-01,
#        -3.73964459e-01, -3.18278730e-01, -1.59108505e-01,  1.19783372e-01,
# ...

# %%
import os
files = os.listdir("CORPUS LEMMA")
matrix_finale = []
for filename in files:
    distances = []
    file1 = open("CORPUS LEMMA/"+filename, encoding='utf-8').read().split(' ')
    txt1 = ' '.join(file1)
    doc1 = nlp(txt1)
    for filename2 in files:
        file2 = open("CORPUS LEMMA/"+filename2, encoding='utf-8').read().split(' ')
        txt2 = ' '.join(file2)
        doc2 = nlp(txt2)
        distances.append((1-doc1.similarity(doc2)))
    matrix_finale.append(distances)
matrix_finale

# %%
import pickle
# Saving the distance matrix
with open('matrix.pkl', 'wb') as file:
    pickle.dump(matrix_finale, file)

# %%
# Loading the distance matrix
import pickle
with open('matrix.pkl', 'rb') as file:
    matrix_finale = pickle.load(file)
    print(matrix_finale)
# Out:
# [[0.0, 0.0540389728246814, 0.07328639926841252, 0.07196545165817458, 0.11002956148468557, 0.07513431321264263, 0.08775763095559064, 0.08198335888404296, 0.08006431875259112, 0.11018078834434708, 0.07062954638320085, 0.11458449981908958, 0.11882885603414106, 0.05158643224229087, 0.048905814901858635, 0.05150945799049944, 0.06951263808664221, 0.07311241894318488, 0.10488410527636116, 0.07260998906548832, 0.10155081948366651, 0.08370383665058889, 0.08345657384401506, 0.08407408060695232, 0.11148579653340296, 0.05024751674431538, 0.09941822890478991, 0.1095445089696212, 0.07705985632839751, 0.05485308374328812, 0.04235665778265918, 0.06219534197931864, 0.07203737020176204, 0.08068416586826699, 0.04194945113304016, 0.05266158986736824, 0.10237382657653693, 0.0819388651893681, 0.0683450954918502, 0.1331316927722338, 0.07613811174022078, 0.02986861929589757, 0.03809301882347582, 0.16378326096595341, 0.09570768718226208, 0.06357631431461552, 0.05992855155375221, 0.07694217741436349, 0.049401
# ...

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np
# continuar a ver o parametro de affinity
clustering = AgglomerativeClustering(affinity='precomputed', linkage='average').fit(matrix_finale)

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram

# Fonction pour afficher le dendrogram
def plot_dendrogram(model, **kwargs):

    # Children of hierarchical clustering
    children = model.children_

    # Distances between each pair of children
    # Since we don't have this information, we can use a uniform one for plotting
    distance = np.arange(children.shape[0])

    # The number of observations contained in each cluster level
    no_of_observations = np.arange(2, children.shape[0]+2)

    # Create linkage matrix and then plot the dendrogram
    linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)
figure = plot.figure(figsize=(50, 30))

# %%
from scipy.cluster.hierarchy import dendrogram
import scipy.spatial.distance as ssd
from matplotlib import pyplot as plot
# %matplotlib inline
import os
files = os.listdir("CORPUS LEMMA")

# convert the redundant n*n square matrix form into a condensed nC2 array
distArray = ssd.squareform(matrix_finale)
Z = linkage(distArray, 'average')
figure = plot.figure(figsize=(50, 30))
dendro = dendrogram(Z, leaf_rotation=0,labels=files, leaf_font_size =12, orientation = 'right')
